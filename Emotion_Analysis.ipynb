# %%
# from keras.models import load_model

# model = load_model("ferNet.h5")

# %%
import cv2
import numpy as np
from keras.models import load_model
from keras.preprocessing import image
import pandas as pd
import time

model = load_model("ferNet.h5")

def get_emotion_counts(video_path):
    
    
    class_names = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    try:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            raise FileNotFoundError(f"Error: Unable to open video file at '{video_path}'")
    except Exception as e:
        print(f"Error: {e}")
        return None
    #cap = cv2.VideoCapture(video_path)

    emotion_counts = pd.DataFrame(columns=['Class', 'Count'])
    start_time = time.time()

    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the frame
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        # Perform emotion prediction for each face
        for (x, y, w, h) in faces:
            face_roi = gray[y:y + h, x:x + w]
            face_roi = cv2.resize(face_roi, (48, 48))
            face_roi = np.expand_dims(face_roi, axis=0)
            face_roi = face_roi.reshape(1, 48, 48, 1)

            # Make predictions for the face
            result = model.predict(face_roi)
            result = list(result[0])
            img_index = result.index(max(result))
            predicted_class_name = class_names.get(img_index, 'Unknown')

            # Update the DataFrame with the prediction
            if predicted_class_name != 'Unknown':
                if predicted_class_name in emotion_counts['Class'].values:
                    index = emotion_counts.index[emotion_counts['Class'] == predicted_class_name][0]
                    emotion_counts.at[index, 'Count'] += 1
                else:
                    new_data = pd.DataFrame({'Class': [predicted_class_name], 'Count': [1]})
                    emotion_counts = pd.concat([emotion_counts, new_data], ignore_index=True)

            # Draw rectangle around the face and display the emotion prediction
            # cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
            # cv2.putText(frame, f'Predicted: {predicted_class_name}', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1,
            #             (255, 255, 255), 2, cv2.LINE_AA)

        #cv2.imshow('Emotion Prediction', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    emotion_counts_new = pd.DataFrame([emotion_counts['Count'].values], columns=emotion_counts['Class'])
    
    #cap.release()
    #cv2.destroyAllWindows()

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Elapsed_time : {elapsed_time} seconds")

    return emotion_counts_new

# Example usage:
video_path = "C:/Users/DIACTO/Downloads/2-3 min introduction video.mp4"
result_df = get_emotion_counts(video_path)
print(result_df)
# Out:
# ...
# 1/1 [==============================] - 0s 109ms/step
# ...
# ...
# 1/1 [==============================] - 0s 111ms/step
# Elapsed_time : 775.0841355323792 seconds
# Class  Fear  Happy  Sad  Neutral
# 0       407   2121  505        7

# %%
print(result_df)
# Out:
# Class  Fear  Happy  Sad  Neutral
# 0       407   2121  505        7

# %%
(result_df)
# Out:
# Class  Fear  Happy  Sad  Neutral
# 0       407   2121  505        7

# %%
import cv2
import numpy as np
from keras.models import load_model
from keras.preprocessing import image
import pandas as pd
import time

model = load_model("D:/Diacto_Data/Dowload_Folder_Data/ferNet.h5")

def get_emotion_counts(video_path):
    
    
    class_names = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    try:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            raise FileNotFoundError(f"Error: Unable to open video file at '{video_path}'")
    except Exception as e:
        print(f"Error: {e}")
        return None
    #cap = cv2.VideoCapture(video_path)

    emotion_counts = pd.DataFrame(columns=['Class', 'Count'])
    start_time = time.time()

    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the frame
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        # Perform emotion prediction for each face
        for (x, y, w, h) in faces:
            face_roi = gray[y:y + h, x:x + w]
            face_roi = cv2.resize(face_roi, (48, 48))
            face_roi = np.expand_dims(face_roi, axis=0)
            face_roi = face_roi.reshape(1, 48, 48, 1)

            # Make predictions for the face
            result = model.predict(face_roi)
            result = list(result[0])
            img_index = result.index(max(result))
            predicted_class_name = class_names.get(img_index, 'Unknown')

            # Update the DataFrame with the prediction
            if predicted_class_name != 'Unknown':
                if predicted_class_name in emotion_counts['Class'].values:
                    index = emotion_counts.index[emotion_counts['Class'] == predicted_class_name][0]
                    emotion_counts.at[index, 'Count'] += 1
                else:
                    new_data = pd.DataFrame({'Class': [predicted_class_name], 'Count': [1]})
                    emotion_counts = pd.concat([emotion_counts, new_data], ignore_index=True)

#             Draw rectangle around the face and display the emotion prediction
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
            cv2.putText(frame, f'Predicted: {predicted_class_name}', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1,
                        (255, 255, 255), 2, cv2.LINE_AA)

        cv2.imshow('Emotion Prediction', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    emotion_counts_new = pd.DataFrame([emotion_counts['Count'].values], columns=emotion_counts['Class'])
    
    cap.release()
    cv2.destroyAllWindows()

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Elapsed_time : {elapsed_time} seconds")

    return emotion_counts_new

# Example usage:
video_path = "C:/Users/Vaishnavi/Downloads/5442623-hd_1280_720_25fps.mp4"
result_df = get_emotion_counts(video_path)
print(result_df)
# Out:
# C:\Users\Vaishnavi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Vaishnavi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# ---------------------------------------------------------------------------
# ...

# %%
import cv2
import numpy as np
import torch
import torchvision.transforms as transforms
from torch import nn
import pandas as pd
import time

# Load the PyTorch model
class FERModel(nn.Module):
    def __init__(self):
        super(FERModel, self).__init__()
        # Define the architecture of the model
        self.model = torch.load("C:/Users/Vaishnavi/Downloads/fer2013_model.pth", map_location=torch.device('cpu'))
    
    def forward(self, x):
        return self.model(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.load("C:/Users/Vaishnavi/Downloads/fer2013_model.pth", map_location=torch.device('cpu'))
model.eval()
model.to(device)

# Define emotion classes
class_names = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

# Transform for preprocessing
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((48, 48)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

def get_emotion_counts(video_path):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    try:
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            raise FileNotFoundError(f"Error: Unable to open video file at '{video_path}'")
    except Exception as e:
        print(f"Error: {e}")
        return None

    emotion_counts = pd.DataFrame(columns=['Class', 'Count'])
    start_time = time.time()

    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        for (x, y, w, h) in faces:
            face_roi = frame[y:y + h, x:x + w]
            face_tensor = transform(face_roi).unsqueeze(0).to(device)

            with torch.no_grad():
                result = model(face_tensor)
                result = torch.softmax(result, dim=1)
                img_index = torch.argmax(result, dim=1).item()
                predicted_class_name = class_names.get(img_index, 'Unknown')

                if predicted_class_name != 'Unknown':
                    if predicted_class_name in emotion_counts['Class'].values:
                        index = emotion_counts.index[emotion_counts['Class'] == predicted_class_name][0]
                        emotion_counts.at[index, 'Count'] += 1
                    else:
                        new_data = pd.DataFrame({'Class': [predicted_class_name], 'Count': [1]})
                        emotion_counts = pd.concat([emotion_counts, new_data], ignore_index=True)

                cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
                cv2.putText(frame, f'Predicted: {predicted_class_name}', (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9,
                            (255, 255, 255), 2)

        cv2.imshow('Emotion Prediction', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Elapsed_time : {elapsed_time} seconds")

    # Format emotion counts DataFrame
    if not emotion_counts.empty:
        emotion_counts = emotion_counts.sort_values(by='Count', ascending=False).reset_index(drop=True)

    return emotion_counts

# Example usage:
video_path = "C:/Users/Vaishnavi/Downloads/5442623-hd_1280_720_25fps.mp4"
result_df = get_emotion_counts(video_path)
print(result_df)
# Out:
# C:\Users\Vaishnavi\AppData\Local\Temp\ipykernel_14912\2488706591.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import cv2
import numpy as np

# Define the SEBlock, ResidualBlock, and ResEmoteNet architectures
class SEBlock(nn.Module):
    def __init__(self, in_channels, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels, bias=False),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)
    
    
class ResidualBlock(nn.Module):
    def __init__(self, in_ch, out_ch, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_ch, out_ch, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_ch)
        self.conv2 = nn.Conv2d(out_ch, out_ch, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_ch)
        
        self.shortcut = nn.Sequential()
        if stride != 1 or in_ch != out_ch:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_ch, out_ch, kernel_size=1, stride=stride, padding=0),
                nn.BatchNorm2d(out_ch)
            )
            
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out
    
    
class ResEmoteNet(nn.Module):
    def __init__(self):
        super(ResEmoteNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.relu = nn.ReLU(inplace=True)
        self.se = SEBlock(256)
        
        self.res_block1 = ResidualBlock(256, 512, stride=2)
        self.res_block2 = ResidualBlock(512, 1024, stride=2)
        self.res_block3 = ResidualBlock(1024, 2048, stride=2)
        
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = nn.Linear(2048, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 256)
        self.dropout1 = nn.Dropout(0.2)
        self.dropout2 = nn.Dropout(0.5)
        self.fc4 = nn.Linear(256, 7)
        
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, 2)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.max_pool2d(x, 2)
        x = self.se(x)
        
        x = self.res_block1(x)
        x = self.res_block2(x)
        x = self.res_block3(x)
        
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.relu(self.fc2(x))
        x = self.dropout2(x)
        x = F.relu(self.fc3(x))
        x = self.dropout2(x)
        x = self.fc4(x)
        return x


# Load the model and weights
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ResEmoteNet().to(device)

# Load the saved state_dict
checkpoint = torch.load("C:/Users/Vaishnavi/Downloads/fer2013_model.pth", map_location=device)
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

# Define emotion classes
class_names = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

# Preprocessing for input images
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Example prediction function
def predict_emotion(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(image_tensor)
        _, predicted = torch.max(outputs, 1)
        emotion = class_names[predicted.item()]
    return emotion

# Test with an image
print(predict_emotion("path_to_image.jpg"))
# Out:
# C:\Users\Vaishnavi\AppData\Local\Temp\ipykernel_10724\3544370211.py:106: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import cv2
import torch
import torchvision.transforms as transforms
from torch.nn import functional as F
import numpy as np

# Define the SEBlock, ResidualBlock, and ResEmoteNet architectures (same as shared earlier)
class SEBlock(nn.Module):
    def __init__(self, in_channels, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)


class ResidualBlock(nn.Module):
    def __init__(self, in_ch, out_ch, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_ch, out_ch, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_ch)
        self.conv2 = nn.Conv2d(out_ch, out_ch, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_ch)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_ch != out_ch:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_ch, out_ch, kernel_size=1, stride=stride, padding=0),
                nn.BatchNorm2d(out_ch)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResEmoteNet(nn.Module):
    def __init__(self):
        super(ResEmoteNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.se = SEBlock(256)

        self.res_block1 = ResidualBlock(256, 512, stride=2)
        self.res_block2 = ResidualBlock(512, 1024, stride=2)
        self.res_block3 = ResidualBlock(1024, 2048, stride=2)

        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = nn.Linear(2048, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 256)
        self.dropout1 = nn.Dropout(0.2)
        self.dropout2 = nn.Dropout(0.5)
        self.fc4 = nn.Linear(256, 7)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.max_pool2d(x, 2)
        x = self.se(x)

        x = self.res_block1(x)
        x = self.res_block2(x)
        x = self.res_block3(x)

        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x


# Load the model and weights
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ResEmoteNet().to(device)

# Load the saved state_dict
checkpoint = torch.load("C:/Users/Vaishnavi/Downloads/fer2013_model.pth", map_location=device)
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

# Define emotion classes
class_names = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

# Preprocessing for input frames
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


# Process video and predict emotions for each frame
def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Unable to open video file {video_path}")
        return

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Convert frame to RGB
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Preprocess the frame
        frame_tensor = transform(rgb_frame).unsqueeze(0).to(device)

        # Predict emotion
        with torch.no_grad():
            outputs = model(frame_tensor)
            _, predicted = torch.max(outputs, 1)
            emotion = class_names[predicted.item()]

        # Display the emotion on the frame
        cv2.putText(frame, f"Emotion: {emotion}", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Show the frame
        cv2.imshow("Emotion Prediction", frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()


# Example usage
video_path = "C:/Users/Vaishnavi/Downloads/5442623-hd_1280_720_25fps.mp4"
process_video(video_path)
# Out:
# C:\Users\Vaishnavi\AppData\Local\Temp\ipykernel_10724\705973580.py:99: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
